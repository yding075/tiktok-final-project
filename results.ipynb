# %%
import sys
import os

sys.path.append("src")

from load import get_youtube_data
from analyze import summarize_by_keyword, plot_results
from trends_analysis import get_trends_data, plot_trends_summary

# %%
df = get_youtube_data()

summary = summarize_by_keyword(df)
summary

# %%
plot_results(df)

# %%
trends_df = get_trends_data()

if trends_df is not None:
    plot_trends_summary(trends_df)
